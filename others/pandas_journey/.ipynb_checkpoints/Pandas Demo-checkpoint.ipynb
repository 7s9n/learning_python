# %%
import pandas as pd
import numpy as np

# %%
na_vals = ['NA' , 'Missing']
df = pd.read_csv('data/survey_results_public.csv' , index_col='Respondent' , na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns' , 61)
pd.set_option('display.max_rows' , 61)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.tail()
# Out:
#            MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# Respondent
# 64858             NaN      Yes  NaN         16      NaN        NaN
# 64867             NaN      Yes  NaN        NaN      NaN        NaN
# 64898             NaN      Yes  NaN        NaN      NaN        NaN
# 64925             NaN      Yes  NaN        NaN      NaN        NaN
# 65112             NaN      Yes  NaN        NaN      NaN        NaN
#
#             ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# Respondent
# 64858                 NaN  United States          NaN            NaN
# 64867                 NaN        Morocco          NaN            NaN
# 64898                 NaN       Viet Nam          NaN            NaN
# 64925                 NaN         Poland          NaN            NaN
# 65112                 NaN          Spain          NaN            NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# ...

# %%
df.shape  #(rows, columns)
# Out:
# (64461, 60)

# %%
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[1, 'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[ [1 , 2 , 3] , 'Hobbyist']
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[ :2 , 'Hobbyist':'Country']
# Out:
#            Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 1               Yes  NaN         13  Monthly        NaN            NaN
# 2                No  NaN         19      NaN        NaN            NaN
#
#                    Country
# Respondent
# 1                  Germany
# 2           United Kingdom

# %%
schema_df.set_index('Column' , inplace=True)

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
df.loc[1]
# Out:
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# DatabaseDesireNextYear                                       Microsoft SQL Server
# ...

# %%
schema_df.loc['MainBranch' , 'QuestionText']
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."'

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
schema_df.sort_index(ascending=False , inplace=True)

# %%
# help(schema_df.sort_index)

# %%
high_salary = ( df['ConvertedComp'] > 5000 )
yemeni_dev = ( df['Country'] == 'Yemen')

# %%
df.loc[yemeni_dev , ['Country' , 'LanguageWorkedWith' , 'ConvertedComp']]
# Out:
#            Country                                 LanguageWorkedWith  \
# Respondent
# 8073         Yemen                        HTML/CSS;JavaScript;PHP;SQL
# 38041        Yemen  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 39232        Yemen                                                NaN
# 62670        Yemen                         C#;HTML/CSS;JavaScript;SQL
# 62960        Yemen                      C#;C++;Dart;HTML/CSS;Java;SQL
# 64285        Yemen                   HTML/CSS;Java;JavaScript;PHP;SQL
# 64634        Yemen              C#;HTML/CSS;JavaScript;SQL;TypeScript
#
#             ConvertedComp
# Respondent
# 8073                  NaN
# 38041                 NaN
# 39232                 NaN
# 62670             36000.0
# 62960                 NaN
# 64285                 NaN
# 64634                 NaN

# %%
countries = ['United States' , 'India' , 'Canada' , 'United Kingdom']
filt = df['Country'].isin(countries)

# %%
df.loc[filt , ['Country' , 'LanguageWorkedWith' , 'ConvertedComp']]
# Out:
#                    Country                       LanguageWorkedWith  \
# Respondent
# 2           United Kingdom                         JavaScript;Swift
# 5            United States                        HTML/CSS;Ruby;SQL
# 7                    India                          C#;HTML/CSS;PHP
# 8            United States                               Python;SQL
# 10          United Kingdom      HTML/CSS;Java;JavaScript;Python;SQL
# ...                    ...                                      ...
# 62834               Canada                            C;C#;C++;Java
# 62954                India                                      SQL
# 63077        United States  C++;HTML/CSS;Java;JavaScript;Python;SQL
# 64236                India                                      NaN
# 64858        United States                                      NaN
#
#             ConvertedComp
# Respondent
# 2                     NaN
# 5                     NaN
# 7                     NaN
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python' , na=False)

# %%
df.loc[filt , ['Country' , 'LanguageWorkedWith' , 'ConvertedComp']]
# Out:
#                        Country  \
# Respondent
# 3           Russian Federation
# 8                United States
# 10              United Kingdom
# 13                 Netherlands
# 15                      France
# ...                        ...
# 61561                   France
# 62391                  Morocco
# 63077            United States
# 63640                Australia
# 64867                  Morocco
#
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 3                                    Objective-C;Python;Swift            NaN
# 8                                                  Python;SQL       116000.0
# 10                        HTML/CSS;Java;JavaScript;Python;SQL        32315.0
# 13                                        C;JavaScript;Python        38916.0
# 15           Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL            NaN
# ...                                                       ...            ...
# ...

# %%
pd.set_option('display.max_rows' , 5)
pd.set_option('display.max_columns' , 5)

# %%
df.rename(columns = {
    'ConvertedComp' : 'SalaryUSD',
} , inplace=True)

df
# Out:
#                                 MainBranch Hobbyist  ...  YearsCode  \
# Respondent                                           ...
# 1           I am a developer by profession      Yes  ...         36
# 2           I am a developer by profession       No  ...          7
# ...                                    ...      ...  ...        ...
# 64925                                  NaN      Yes  ...        NaN
# 65112                                  NaN      Yes  ...        NaN
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# ...                 ...
# 64925               NaN
# 65112               NaN
#
# [64461 rows x 60 columns]

# %%
df['SalaryUSD'].count() #number of non-NA/null observations in the Series.
# Out:
# 34756

# %%
df['Hobbyist'].replace({
    'Yes' : True , 
    'No' : False
} , inplace=True)

# %%
# df['Hobbyist'] = df['Hobbyist'].map({
#     'Yes' : True , 
#     'No' : False,
# })

# %%
df['Hobbyist']
# Out:
# Respondent
# 1         True
# 2        False
#          ...
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
pd.set_option('display.max_rows' , 50)
pd.set_option('display.max_columns' , 60)

# %%
df.sort_values( by=['Country' , 'SalaryUSD'] , ascending=[True , False] , inplace=True)

# %%
df[ ['Country' , 'SalaryUSD'] ].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 62788       Afghanistan  1000000.0
# 65381       Afghanistan  1000000.0
# 65456       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 28374       Afghanistan   130000.0
# 9839        Afghanistan    23328.0
# 63848       Afghanistan    23328.0
# 51862       Afghanistan    20950.0
# 51509       Afghanistan    20220.0
# 44484       Afghanistan    18660.0
# 15422       Afghanistan    18000.0
# 2932        Afghanistan    16335.0
# 26540       Afghanistan    13992.0
# 57269       Afghanistan    10884.0
# 26775       Afghanistan     8016.0
# 30568       Afghanistan     5448.0
# 30522       Afghanistan     4668.0
# 28811       Afghanistan     4509.0
# 34969       Afghanistan     4356.0
# 26857       Afghanistan     2328.0
# 33878       Afghanistan     1860.0
# 35753       Afghanistan      780.0
# 18049       Afghanistan      109.0
# 35295       Afghanistan        0.0
# 898         Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(5 , 'SalaryUSD')
# Out:
#                                 MainBranch Hobbyist   Age  \
# Respondent
# 5725        I am a developer by profession    False  26.0
# 54263       I am a developer by profession     True  29.0
# 43430       I am a developer by profession     True  33.0
# 59279       I am a developer by profession     True   NaN
# 46711       I am a developer by profession     True   NaN
#
#                       Age1stCode CompFreq     CompTotal  SalaryUSD  Country  \
# Respondent
# 5725                          14  Monthly  1.800000e+05  2000000.0   Canada
# 54263                         10   Weekly  7.000000e+04  2000000.0   Canada
# 43430                         17  Monthly  1.710000e+05  2000000.0    Italy
# 59279                         12  Monthly  3.000000e+05  2000000.0    Nepal
# 46711       Younger than 5 years   Yearly  1.000000e+56  2000000.0  Nomadic
#
#                     CurrencyDesc CurrencySymbol  \
# Respondent
# 5725        United States dollar            USD
# ...

# %%
df.nsmallest(5 , 'SalaryUSD')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession     True   NaN         13  Monthly
# 47357       I am a developer by profession     True   NaN          5   Weekly
# 6054        I am a developer by profession     True  38.0         15   Yearly
# 27135       I am a developer by profession    False   NaN         16   Yearly
# 60292       I am a developer by profession     True   NaN         12   Yearly
#
#             CompTotal  SalaryUSD      Country        CurrencyDesc  \
# Respondent
# 35295             2.0        0.0  Afghanistan      Afghan afghani
# 47357             1.0        0.0      Albania  Bhutanese ngultrum
# 6054              0.0        0.0    Australia   Australian dollar
# 27135             0.0        0.0    Australia   Australian dollar
# 60292             0.0        0.0      Austria       European Euro
#
# ...

# %%
df['SalaryUSD'].head(15)
# Out:
# Respondent
# 62788    1000000.0
# 65381    1000000.0
# 65456    1000000.0
# 38672     231192.0
# 28374     130000.0
# 9839       23328.0
# 63848      23328.0
# 51862      20950.0
# 51509      20220.0
# 44484      18660.0
# 15422      18000.0
# 2932       16335.0
# 26540      13992.0
# 57269      10884.0
# 26775       8016.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 54049.0

# %%
df.median() #in a future version this will raise TypeError.
# Out:
# <ipython-input-40-1794fc0b7e28>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median() #in a future version this will raise TypeError.
# Hobbyist           1.0
# Age               29.0
# CompTotal      63000.0
# SalaryUSD      54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal     SalaryUSD   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['SalaryUSD'].count()
# Out:
# 34756

# %%
df['Hobbyist'].value_counts()
# Out:
# True     50388
# False    14028
# Name: Hobbyist, dtype: int64

# %%
df['OpSys'].value_counts()
# Out:
# Windows        27170
# Linux-based    14932
# MacOS          14075
# BSD               51
# Name: OpSys, dtype: int64

# %%
df['OpSys'].value_counts(normalize=True)
# Out:
# Windows        0.483211
# Linux-based    0.265562
# MacOS          0.250320
# BSD            0.000907
# Name: OpSys, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Liechtenstein           1
# Mali                    1
# Marshall Islands        1
# Nauru                   1
# Lesotho                 1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp = df.groupby( ['Country'] )

# %%
country_grp.get_group('India')['OpSys'].value_counts()
# Out:
# Windows        3426
# Linux-based    2077
# MacOS          1158
# BSD               5
# Name: OpSys, dtype: int64

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['OpSys'].value_counts()
# Out:
# Windows        4874
# MacOS          4082
# Linux-based    2445
# BSD               8
# Name: OpSys, dtype: int64

# %%
filt = df['OpSys'] == 'Linux-based'
df[filt]['OpSys'].count()
# Out:
# 14932

# %%
country_grp['OpSys'].value_counts().head()
# Out:
# Country      OpSys
# Afghanistan  Windows        31
#              Linux-based     8
#              MacOS           5
# Albania      Windows        24
#              MacOS           7
# Name: OpSys, dtype: int64

# %%
country_grp['OpSys'].value_counts(normalize=True).loc['United States']
# Out:
# OpSys
# Windows        0.427207
# MacOS          0.357788
# Linux-based    0.214304
# BSD            0.000701
# Name: OpSys, dtype: float64

# %%
# country_grp['SalaryUSD'].median().loc['Yemen']
country_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: SalaryUSD, Length: 183, dtype: float64

# %%
# country_grp['SalaryUSD'].agg(['median' , 'mean']).loc['Yemen'] return series
country_grp['SalaryUSD'].agg(['median' , 'mean']) #return DataFrame
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
filt = df['Country'] == 'Germany'
# df.loc[filt , 'LanguageWorkedWith'].str.contains('Python').sum()
df[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 1712

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_respondent = df['Country'].value_counts()
country_respondent
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Liechtenstein           1
# Mali                    1
# Marshall Islands        1
# Nauru                   1
# Lesotho                 1
# Name: Country, Length: 183, dtype: int64

# %%
new_df = pd.concat([country_respondent , country_uses_python] , axis=1)
new_df.rename(columns={
    'Country':'NumberOfRespondent',
    'LanguageWorkedWith':'NumKnowsPython'
} , inplace=True)
new_df
# Out:
#                   NumberOfRespondent  NumKnowsPython
# United States                  12469            5964
# India                           8403            2670
# United Kingdom                  3896            1621
# Germany                         3890            1712
# Canada                          2191            1011
# ...                              ...             ...
# Liechtenstein                      1               0
# Mali                               1               0
# Marshall Islands                   1               0
# Nauru                              1               0
# Lesotho                            1               0
#
# [183 rows x 2 columns]

# %%
new_df['PCTKnowsPython'] = (new_df['NumKnowsPython'] / new_df['NumberOfRespondent']) * 100

# %%
new_df.sort_values(by=['PCTKnowsPython'] , ascending=False)
# Out:
#                                     NumberOfRespondent  NumKnowsPython  \
# Saint Lucia                                          1               1
# Gabon                                                1               1
# Micronesia, Federated States of...                   1               1
# Montenegro                                          13               9
# Brunei Darussalam                                    3               2
# ...                                                ...             ...
# Saint Vincent and the Grenadines                     3               0
# Burundi                                              2               0
# Cape Verde                                           2               0
# San Marino                                           2               0
# Lesotho                                              1               0
#
#                                     PCTKnowsPython
# Saint Lucia                             100.000000
# ...

# %%
new_df.loc['Japan']
# Out:
# NumberOfRespondent    297.000000
# NumKnowsPython        132.000000
# PCTKnowsPython         44.444444
# Name: Japan, dtype: float64

# %%
df['YearsCode'] = df['YearsCode'].fillna('0')
df['YearsCode'] = df['YearsCode'].str.extract('(\d+)' , expand=False).astype(np.uint8)
(df['YearsCode'] > 0).value_counts()
# Out:
# True     57684
# False     6777
# Name: YearsCode, dtype: int64
