# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df.loc[df['WebframeWorkedWith'] == 'Django']
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 82             83                     I am a developer by profession      Yes
# 260           262                     I am a developer by profession      Yes
# 374           376                     I am a developer by profession      Yes
# 521           523                     I am a developer by profession      Yes
# 623           625  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 63493       64910                     I am a developer by profession      Yes
# 63567       64990  I am not primarily a developer, but I write co...      Yes
# 63767       65205                     I am a developer by profession      Yes
# 64217       16274                                                NaN      Yes
# 64427       60149                                                NaN      Yes
#
# ...
